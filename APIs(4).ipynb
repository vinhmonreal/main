# %% [markdown]
# # APIs

# %% [markdown]
# ## Tasks Today:
# 1) <b>Requests and the pokemon API </b> <br>

# %% [markdown]
# # working with APis

# %% [markdown]
# <p> What exactly is an API? <br> <br>
# API is the acronym for Application Programming Interface, which is a software intermediary that allows two applications to talk to each other. Each time you use an app like Facebook, send an instant message, or check the weather on your phone, you're using an API. </p>

# %% [markdown]
# ### The Poke API  allows you to retreive a pokemon's information from PokeAPI https://pokeapi.co/

# %%
# making an API call
import requests

pokemon = input('What pokemon do you want information for?')

response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon}')

if response.status_code == 200:
    print('SUCCESS')
    data = response.json()
else:
    print(f'ERROR, STATUS CODE {response.status_code}')
# Out:
# What pokemon do you want information for?psyduck
# SUCCESS

# %%
print(data['name'])
# Out:
# psyduck

# %% [markdown]
# ### Display a Pokemon's name, weight, abilities, and types

# %%
# get the name
name = data['name']
print(name)
# Out:
# psyduck

# %%
# get types
data['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}]

# %%
# get weight
data['weight']
# Out:
# 196

# %%
# get abilities
data['abilities']
# Out:
# [{'ability': {'name': 'damp', 'url': 'https://pokeapi.co/api/v2/ability/6/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'cloud-nine',
#    'url': 'https://pokeapi.co/api/v2/ability/13/'},
#   'is_hidden': False,
#   'slot': 2},
#  {'ability': {'name': 'swift-swim',
#    'url': 'https://pokeapi.co/api/v2/ability/33/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
ability_names = [item['ability']['name'] for item in data['abilities']]

# %%
ability_names
# Out:
# ['damp', 'cloud-nine', 'swift-swim']

# %%
# Create a structure for a single pokemon
pokemon = {
    'abilities': ability_names,
    'name': data['name'],
    'types': data['types'],
    'weight': data['weight']
}

# %%
pokemon
# Out:
# {'abilities': ['damp', 'cloud-nine', 'swift-swim'],
#  'name': 'psyduck',
#  'types': [{'slot': 1,
#    'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}],
#  'weight': 196}

# %% [markdown]
# #### Create a function to Pull in your own Pokemon's data

# %%
# Create a function that does the following:
# Asks a user to input a pokemon name
# Requests the poke api for that pokemon's information
# Creates the dictionary from above with that pokemons information
    # In addition to the above keys, include the height and the "front_default" sprite
# Returns the dictionary

def poke_api_call(pokemon=None):
    if not pokemon:
        pokemon = input('What pokemon do you want to select?')
    
    response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon}')

    if response.status_code == 200:
        print('SUCCESS')
        data = response.json()
    else:
        print(f'ERROR, STATUS CODE {response.status_code}')
        return 'Error'
    
    ability_names = [item['ability']['name'] for item in data['abilities']]
    
    poke_dict = {
        'abilities': ability_names,
        'name': data['name'],
        'types': data['types'],
        'weight': data['weight'],
        'height': data['height'],
        'sprite': data['sprites']['front_default']
    }
    
    return poke_dict

# %%
poke_api_call('pikachu')
# Out:
# SUCCESS
# {'abilities': ['static', 'lightning-rod'],
#  'name': 'pikachu',
#  'types': [{'slot': 1,
#    'type': {'name': 'electric', 'url': 'https://pokeapi.co/api/v2/type/13/'}}],
#  'weight': 60,
#  'height': 4,
#  'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/25.png'}

# %%
# Out:
# What pokemon do you want to select?pikachu
# SUCCESS
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-ef94367159f3> in <module>
# ----> 1 poke_api_call()*6
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %% [markdown]
# Choose your pokemon

# %%
from random import randint
# Random number generated for each pokemon id
random_team = [randint(1,898) for i in range(6)]

your_team = ['electabuzz', 'haunter','tyranitar','blaziken','marowak','dragonair']


your_team_pokemon = []

for teammate in your_team:
    your_team_pokemon.append(poke_api_call(teammate))
# Out:
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS

# %%
list(map(poke_api_call, your_team))
# Out:
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# [{'abilities': ['static', 'vital-spirit'],
#   'name': 'electabuzz',
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}],
#   'weight': 300,
#   'height': 11,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/125.png'},
#  {'abilities': ['levitate'],
#   'name': 'haunter',
#   'types': [{'slot': 1,
#     'type': {'name': 'ghost', 'url': 'https://pokeapi.co/api/v2/type/8/'}},
#    {'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}],
#   'weight': 1,
#   'height': 16,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/93.png'},
#  {'abilities': ['sand-stream', 'unnerve'],
#   'name': 'tyranitar',
#   'types': [{'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}},
#    {'slot': 2,
#     'type': {'name': 'dark', 'url': 'https://pokeapi.co/api/v2/type/17/'}}],
#   'weight': 2020,
#   'height': 20,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/248.png'},
#  {'abilities': ['blaze', 'speed-boost'],
#   'name': 'blaziken',
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}},
#    {'slot': 2,
#     'type': {'name': 'fighting', 'url': 'https://pokeapi.co/api/v2/type/2/'}}],
#   'weight': 520,
#   'height': 19,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/257.png'},
#  {'abilities': ['rock-head', 'lightning-rod', 'battle-armor'],
#   'name': 'marowak',
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}],
#   'weight': 450,
#   'height': 10,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/105.png'},
#  {'abilities': ['shed-skin', 'marvel-scale'],
#   'name': 'dragonair',
#   'types': [{'slot': 1,
#     'type': {'name': 'dragon', 'url': 'https://pokeapi.co/api/v2/type/16/'}}],
#   'weight': 165,
#   'height': 40,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/148.png'}]

# %%
your_team_pokemon
# Out:
# [{'abilities': ['static', 'vital-spirit'],
#   'name': 'electabuzz',
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}],
#   'weight': 300,
#   'height': 11,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/125.png'},
#  {'abilities': ['levitate'],
#   'name': 'haunter',
#   'types': [{'slot': 1,
#     'type': {'name': 'ghost', 'url': 'https://pokeapi.co/api/v2/type/8/'}},
#    {'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}],
#   'weight': 1,
#   'height': 16,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/93.png'},
#  {'abilities': ['sand-stream', 'unnerve'],
#   'name': 'tyranitar',
#   'types': [{'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}},
#    {'slot': 2,
#     'type': {'name': 'dark', 'url': 'https://pokeapi.co/api/v2/type/17/'}}],
#   'weight': 2020,
#   'height': 20,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/248.png'},
#  {'abilities': ['blaze', 'speed-boost'],
#   'name': 'blaziken',
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}},
#    {'slot': 2,
#     'type': {'name': 'fighting', 'url': 'https://pokeapi.co/api/v2/type/2/'}}],
#   'weight': 520,
#   'height': 19,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/257.png'},
#  {'abilities': ['rock-head', 'lightning-rod', 'battle-armor'],
#   'name': 'marowak',
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}],
#   'weight': 450,
#   'height': 10,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/105.png'},
#  {'abilities': ['shed-skin', 'marvel-scale'],
#   'name': 'dragonair',
#   'types': [{'slot': 1,
#     'type': {'name': 'dragon', 'url': 'https://pokeapi.co/api/v2/type/16/'}}],
#   'weight': 165,
#   'height': 40,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/148.png'}]

# %%
random_team
# Out:
# [245, 333, 191, 436, 392, 105]

# %%
random_team_pokemon = []

for teammate in random_team:
    random_team_pokemon.append(poke_api_call(teammate))
# Out:
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS

# %%
random_team_pokemon
# Out:
# [{'abilities': ['pressure', 'inner-focus'],
#   'name': 'suicune',
#   'types': [{'slot': 1,
#     'type': {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'}}],
#   'weight': 1870,
#   'height': 20,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/245.png'},
#  {'abilities': ['natural-cure', 'cloud-nine'],
#   'name': 'swablu',
#   'types': [{'slot': 1,
#     'type': {'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'}},
#    {'slot': 2,
#     'type': {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'}}],
#   'weight': 12,
#   'height': 4,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/333.png'},
#  {'abilities': ['chlorophyll', 'solar-power', 'early-bird'],
#   'name': 'sunkern',
#   'types': [{'slot': 1,
#     'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}}],
#   'weight': 18,
#   'height': 3,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/191.png'},
#  {'abilities': ['levitate', 'heatproof', 'heavy-metal'],
#   'name': 'bronzor',
#   'types': [{'slot': 1,
#     'type': {'name': 'steel', 'url': 'https://pokeapi.co/api/v2/type/9/'}},
#    {'slot': 2,
#     'type': {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'}}],
#   'weight': 605,
#   'height': 5,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/436.png'},
#  {'abilities': ['blaze', 'iron-fist'],
#   'name': 'infernape',
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}},
#    {'slot': 2,
#     'type': {'name': 'fighting', 'url': 'https://pokeapi.co/api/v2/type/2/'}}],
#   'weight': 550,
#   'height': 12,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/392.png'},
#  {'abilities': ['rock-head', 'lightning-rod', 'battle-armor'],
#   'name': 'marowak',
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}],
#   'weight': 450,
#   'height': 10,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/105.png'}]

# %% [markdown]
# #### Use your function to create a dictionary of your Johto League 6  (favorite 6 pokemon)

# %%
# Place all 6 of your pokemon on the object below, each pokemon should have at least as much info as Pikachu did.
my_six_pokemon = {}

for teammate in your_team:
    my_six_pokemon[teammate] = poke_api_call(teammate)
# Out:
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS

# %%
my_six_pokemon
# Out:
# {'electabuzz': {'abilities': ['static', 'vital-spirit'],
#   'name': 'electabuzz',
#   'types': [{'slot': 1,
#     'type': {'name': 'electric',
#      'url': 'https://pokeapi.co/api/v2/type/13/'}}],
#   'weight': 300,
#   'height': 11,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/125.png'},
#  'haunter': {'abilities': ['levitate'],
#   'name': 'haunter',
#   'types': [{'slot': 1,
#     'type': {'name': 'ghost', 'url': 'https://pokeapi.co/api/v2/type/8/'}},
#    {'slot': 2,
#     'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}],
#   'weight': 1,
#   'height': 16,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/93.png'},
#  'tyranitar': {'abilities': ['sand-stream', 'unnerve'],
#   'name': 'tyranitar',
#   'types': [{'slot': 1,
#     'type': {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'}},
#    {'slot': 2,
#     'type': {'name': 'dark', 'url': 'https://pokeapi.co/api/v2/type/17/'}}],
#   'weight': 2020,
#   'height': 20,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/248.png'},
#  'blaziken': {'abilities': ['blaze', 'speed-boost'],
#   'name': 'blaziken',
#   'types': [{'slot': 1,
#     'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}},
#    {'slot': 2,
#     'type': {'name': 'fighting', 'url': 'https://pokeapi.co/api/v2/type/2/'}}],
#   'weight': 520,
#   'height': 19,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/257.png'},
#  'marowak': {'abilities': ['rock-head', 'lightning-rod', 'battle-armor'],
#   'name': 'marowak',
#   'types': [{'slot': 1,
#     'type': {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'}}],
#   'weight': 450,
#   'height': 10,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/105.png'},
#  'dragonair': {'abilities': ['shed-skin', 'marvel-scale'],
#   'name': 'dragonair',
#   'types': [{'slot': 1,
#     'type': {'name': 'dragon', 'url': 'https://pokeapi.co/api/v2/type/16/'}}],
#   'weight': 165,
#   'height': 40,
#   'sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/148.png'}}

# %% [markdown]
# ## Lets create a class called 'Pokemon' and create our pokemon as instances

# %%
poke_dict = {
    'abilities': ability_names,
    'name': data['name'],
    'types': data['types'],
    'weight': data['weight'],
    'height': data['height'],
    'sprite': data['sprites']['front_default']
}

# %%
class Pokemon():
    def __init__(self, name):
        self.abilities = []
        self.name = name
        self.types = []
        self.weight = None
        self.height = None
        self.sprite = None
        self.poke_api_call()
        
    def poke_api_call(self):
        response = requests.get(f'https://pokeapi.co/api/v2/pokemon/{self.name}')

        if response.status_code == 200:
            data = response.json()
        else:
            return 'Error'

        ability_names = [item['ability']['name'] for item in data['abilities']]
        
        self.types = data['types']
        self.abilities = ability_names
        self.weight = data['weight']
        self.height = data['height']
        self.sprite = data['sprites']['front_default']
        
    def evolve(self):
        new_poke = input("What pokemon should you evolve into?")
        self.name = new_poke
        self.poke_api_call()

# %%
pikachu = Pokemon('pikachu')

# %%
print(pikachu.weight)
# Out:
# 60

# %% [markdown]
# ### Let's Catch some Pokemon

# %%
class Pokedex:
    def __init__(self, player_name):
        self.player_name = player_name
        self.pokemon = {}
        
    def add_pokemon(self, name):
        self.pokemon[name] = Pokemon(name)
        print(f"{name} was added to {self.player_name}'s pokedex.")

    # Add a pokemon lookup method to lookup a pokemon and display it's information (In a user friendly way)

# %%
dylans_pokedex = Pokedex('dylan')

# %%
dylans_pokedex.add_pokemon('ho-oh')
# Out:
# ho-oh was added to dylan's pokedex.

# %%
dylans_pokedex.pokemon
# Out:
# {'ho-oh': <__main__.Pokemon at 0x2107d300a20>}

# %% [markdown]
# ## Exercise 1:

# %% [markdown]
# ### Create a Method prints an image of your pokemon
#
# <p>HINT: You may need another attribute as well to store your image url within. </p>

# %%
# Display an image in Jupyter notebook
from IPython.display import Image

display(Image('https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/133.png', width = 200))

# %%
# recreate your pokemon class here
from requests import get
class Pokemon:
    def __init__(self, name):
        self.name = name
        self.ability = []
        self.weight = None
        self.species = []
        self.image = []
        self.type = []
        self.call_api()
    def call_api(self):
        response = get(f'https://pokeapi.co/api/v2/pokemon/{self.name}')
        if response.status_code == 200:
            print('Success')
            data = response.json()
            self.species_url = data['species']['url']
            self.name = data['name']
            self.abilites = [ability_object['ability']['name'] for ability_object in data['abilities']],
            self.types = [type_object['type']['name'] for type_object in data['types']]
            self.weight = data['weight']
            self.image = data['sprites']['versions']['generation-v']['black-white']['animated']['front_default']
            if not self.image:
                self.image = data['sprites']['front_default']
            display(Image(self.image, width = 200))
        else:
            print('Failed')

# %%
class Pokedex():
    def __init__(self, user):
        self.user = user
        self.pokemon_dict = {}
    def add_pokemon(self, name):
        self.pokemon_dict[name] = Pokemon(name)  
        print(f'{name} was added to the Pokedex')

# %%
# Calling our new method
my_pokemon = Pokemon('eevee')
my_pokedex = Pokedex('Vinh')
my_pokedex.add_pokemon('pikachu')
my_pokedex.add_pokemon('sandslash')
my_pokedex.add_pokemon('jolteon')
my_pokedex.add_pokemon('dragonite')
my_pokedex.add_pokemon('ponyta')
my_pokedex.add_pokemon('blastoise')
# Out:
# Success
# Success
# pikachu was added to the Pokedex
# Success
# sandslash was added to the Pokedex
# Success
# jolteon was added to the Pokedex
# Success
# dragonite was added to the Pokedex
# Success
# ponyta was added to the Pokedex
# Success
# blastoise was added to the Pokedex

# %% [markdown]
# ## Exercise 2:

# %% [markdown]
# ### Create a Method that evolves your Pokemon
# If your pokemon can't evolve any further print a message that says "\<name of pokemon> can't evolve."

# %%
# Create a method for your Pokemon class that takes in user input, 
# to ask what new pokemon your current pokemon should evolve into.
from requests import get
from IPython.display import Image

class Pokemon:
    def __init__(self, name):
        self.name = name
        self.ability = []
        self.weight = None
        self.species = []
        self.image = []
        self.type = []
        self.driver()

    
    def driver(self):
        response = input("What pokemon do you want to get?")
        a = self.call_api(response)
        while a:
            self.get_evolution_chain()
            res = input(f"What pokemon do you want {response} to evolve into?")
            self.call_api(res)    
        else:
            print(f'{response} is not available')
            
    def call_api(self,name):
        response = get(f'https://pokeapi.co/api/v2/pokemon/{name}')
        if response.status_code == 200:
            print('Success')
            data = response.json()
            self.species_url = data['species']['url']
            self.name = data['name']
            self.abilites = [ability_object['ability']['name'] for ability_object in data['abilities']],
            self.types = [type_object['type']['name'] for type_object in data['types']]
            self.weight = data['weight']
            self.image = data['sprites']['versions']['generation-v']['black-white']['animated']['front_default']
            if not self.image:
                self.image = data['sprites']['front_default']
            display(Image(self.image, width = 200))
            self.get_evolution_chain()
            return True
        else:
            print('Failed')
            return False
    def get_evolution_chain(self):
        response = get(self.species_url)
        if response.status_code == 200:
            data = response.json()
        self.evolution_chain = get(data['evolution_chain']['url'])
        if self.evolution_chain.status_code == 200:
            return self.evolution_chain.json()['chain']

# %%
my = Pokemon(name=None)
# Out:
# Success
# Success

# %%
# Create a method
# Take in user input, should be a pokemons name
# Update the current pokemon's attributes (their height, weight, sprite, etc.) to the new pokemon's values

# %% [markdown]
# Now let's evolve a few

# %%
pikachu = Pokemon('pikachu')

print(pikachu.sprite)
# Out:
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/25.png

# %%
pikachu.evolve()
# Out:
# What pokemon should you evolve into?raichu

# %%
pikachu.sprite
# Out:
# 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/26.png'

# %% [markdown]
# #  Final Exercise (Optional): <br> <br>Create a Move_Tutor Class that will allow the Pokemon Class to inherit a move list.
# <br>
# <p>for an added bonus you can make sure that if a pokemon has 4 moves the user can choose one of them to replace with a new move. </p>

# %%
class Move_Tutor:
    def __init__(self):
        self.move_list = []

# %%
pikachu.teach_move()
# Out:
# What move would you like to teach pikachu? spark
# pikachu learned spark!

# %%
pikachu.show_moves()
# Out:
# pikachu's moves'
# thunder
# surf
# earthquake
